# %% [markdown]
# # **YOLOv8 Rust Detection Model**
#
# This model follows the same basic format of the crack detection model. See crack detection model for code comments and explainations.  While the model does train, it is trained on a much smaller dataset than the crack detector. Each individual image in the dataset is also more complex. As a result, using the same method and interations in training yields a significantly less accurate model. The model does run and work, but it is far less accurate than the crack detector. However, it is proof of concenpt and could be further developed/optimized for future scale up and commercial implementation.

# %%
# %pip install ultralytics==8.0.196

# Imports
from IPython import display
display.clear_output()

import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.0.196  Python-3.10.11 torch-2.2.2+cpu CPU (AMD Ryzen 5 7600X 6-Core Processor)
# Setup complete  (12 CPUs, 63.7 GB RAM, 950.0/1862.3 GB disk)

# %%
from ultralytics import YOLO

from IPython.display import display, Image

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="I7TvMqoU2PXUBlvTFsKE")
project = rf.workspace("rust-rs7xg").project("rust_detection-z0b0c")
version = project.version(1)
dataset = version.download("yolov8-obb")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...

# %%
# !yolo task=detect mode=train model=yolov8s.pt data="C:\\Users\\Marcus\\Desktop\\Share Folder\\yolov8-rust-detection\\rust_detection-1\\data.yaml" epochs=30 imgsz=800 plots=True

# %% [markdown]
# Note: This cell was executed in the powershell terminal so that the output was continually displayed (not the case in a VS Code Jupyter Notebook). The output was as follows:
#
# New https://pypi.org/project/ultralytics/8.2.2 available  Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.0.196  Python-3.10.11 torch-2.0.1+cu117 CUDA:0 (NVIDIA GeForce RTX 4070 Ti, 12282MiB)
# engine\trainer: task=detect, mode=train, model=yolov8s.pt, data=C:\\Users\\Marcus\\Desktop\\Share Folder\\yolov8-rust-detection\\rust_detection-1\\data.yaml, epochs=30, patience=50, batch=16, imgsz=800, save=True, save_period=-1, cache=False, device=None, workers=8, project=None, name=None, exist_ok=False, pretrained=True, optimizer=auto, verbose=True, seed=0, deterministic=True, single_cls=False, rect=False, cos_lr=False, close_mosaic=10, resume=False, amp=True, fraction=1.0, profile=False, freeze=None, overlap_mask=True, mask_ratio=4, dropout=0.0, val=True, split=val, save_json=False, save_hybrid=False, conf=None, iou=0.7, max_det=300, half=False, dnn=False, plots=True, source=None, show=False, save_txt=False, save_conf=False, save_crop=False, show_labels=True, show_conf=True, vid_stride=1, stream_buffer=False, line_width=None, visualize=False, augment=False, agnostic_nms=False, classes=None, retina_masks=False, boxes=True, format=torchscript, keras=False, optimize=False, int8=False, dynamic=False, simplify=False, opset=None, workspace=4, nms=False, lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=7.5, cls=0.5, dfl=1.5, pose=12.0, kobj=1.0, label_smoothing=0.0, nbs=64, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, mosaic=1.0, mixup=0.0, copy_paste=0.0, cfg=None, tracker=botsort.yaml, save_dir=runs\detect\train6
# Overriding model.yaml nc=80 with nc=1
#
#                    from  n    params  module
#              arguments
#   0                  -1  1       928  ultralytics.nn.modules.conv.Conv             [3, 32, 3, 2]
#   1                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   2                  -1  1     29056  ultralytics.nn.modules.block.C2f             [64, 64, 1, True]
#   3                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   4                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   5                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   6                  -1  2    788480  ultralytics.nn.modules.block.C2f             [256, 256, 2, True]
#   7                  -1  1   1180672  ultralytics.nn.modules.conv.Conv             [256, 512, 3, 2]
#   8                  -1  1   1838080  ultralytics.nn.modules.block.C2f             [512, 512, 1, True]
#   9                  -1  1    656896  ultralytics.nn.modules.block.SPPF            [512, 512, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  12                  -1  1    591360  ultralytics.nn.modules.block.C2f             [768, 256, 1]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  15                  -1  1    148224  ultralytics.nn.modules.block.C2f             [384, 128, 1]
#  16                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  18                  -1  1    493056  ultralytics.nn.modules.block.C2f             [384, 256, 1]
#  19                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  21                  -1  1   1969152  ultralytics.nn.modules.block.C2f             [768, 512, 1]
#  22        [15, 18, 21]  1   2116435  ultralytics.nn.modules.head.Detect           [1, [128, 256, 512]]
# Model summary: 225 layers, 11135987 parameters, 11135971 gradients, 28.6 GFLOPs
#
# Transferred 349/355 items from pretrained weights
# Freezing layer 'model.22.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks with YOLOv8n...
# Downloading https://github.com/ultralytics/assets/releases/download/v0.0.0/yolov8n.pt to 'yolov8n.pt'...
# 100%|███████████████████████████| 6.23M/6.23M [00:00<00:00, 36.5MB/s]
# AMP: checks passed
# train: Scanning C:\Users\Marcus\Desktop\Share Folder\yolov8-rust-dete
# train: New cache created: C:\Users\Marcus\Desktop\Share Folder\yolov8-rust-detection\rust_detection-1\train\labels.cache
# val: Scanning C:\Users\Marcus\Desktop\Share Folder\yolov8-rust-detect
# val: New cache created: C:\Users\Marcus\Desktop\Share Folder\yolov8-rust-detection\rust_detection-1\valid\labels.cache
# Plotting labels to runs\detect\train6\labels.jpg...
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.002, momentum=0.9) with parameter groups 57 weight(decay=0.0), 64 weight(decay=0.0005), 63 bias(decay=0.0)
# Image sizes 800 train, 800 val
# Using 8 dataloader workers
# Logging results to runs\detect\train6
# Starting training for 30 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        1/30      9.55G      2.875      3.097      2.326        445
#                  Class     Images  Instances      Box(P          R
#                    all         32        399     0.0583      0.108     0.0214    0.00576
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        2/30      8.95G      2.747      2.703      2.208        272
#                  Class     Images  Instances      Box(P          R
#                    all         32        399     0.0216     0.0977    0.00825    0.00239
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        3/30      8.12G      2.742      2.602      2.209        461
#                  Class     Images  Instances      Box(P          R
#                    all         32        399     0.0454      0.133     0.0202    0.00543
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        4/30      9.53G      2.708      2.599      2.227        253
#                  Class     Images  Instances      Box(P          R
#                    all         32        399     0.0356     0.0902     0.0136    0.00439
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        5/30       8.9G      2.736      2.536      2.183        318
#                  Class     Images  Instances      Box(P          R
#                    all         32        399     0.0287     0.0326     0.0111    0.00416
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        6/30      9.09G      2.662      2.521      2.167        368
#                  Class     Images  Instances      Box(P          R
#                    all         32        399     0.0722      0.128     0.0382    0.00967
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        7/30      9.07G      2.607      2.509      2.136        547
#                  Class     Images  Instances      Box(P          R
#                    all         32        399     0.0765      0.113     0.0283    0.00874
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        8/30      8.48G      2.623      2.484      2.139        275
#                  Class     Images  Instances      Box(P          R
#                    all         32        399      0.114      0.155     0.0463     0.0116
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        9/30      9.47G      2.555      2.446      2.132        453
#                  Class     Images  Instances      Box(P          R
#                    all         32        399       0.09       0.12     0.0418     0.0119
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       10/30      9.81G      2.541      2.485      2.151        143
#                  Class     Images  Instances      Box(P          R
#                    all         32        399      0.152      0.144     0.0685     0.0169
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       11/30      8.91G      2.579      2.485      2.095        290
#                  Class     Images  Instances      Box(P          R
#                    all         32        399     0.0877     0.0977     0.0357    0.00925
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       12/30      10.4G      2.535      2.413      2.059        404
#                  Class     Images  Instances      Box(P          R
#                    all         32        399      0.125      0.117     0.0618     0.0161
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       13/30      9.03G      2.503      2.405      2.056        256
#                  Class     Images  Instances      Box(P          R
#                    all         32        399     0.0994      0.133     0.0385     0.0118
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       14/30       9.7G       2.45      2.335      2.028        324
#                  Class     Images  Instances      Box(P          R
#                    all         32        399      0.126      0.125     0.0513     0.0139
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       15/30      9.05G      2.469       2.33      2.011        273
#                  Class     Images  Instances      Box(P          R
#                    all         32        399      0.137       0.14     0.0572      0.016
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       16/30      9.12G      2.449      2.318      2.011        376
#                  Class     Images  Instances      Box(P          R
#                    all         32        399     0.0977     0.0927     0.0429     0.0132
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       17/30      8.54G      2.457      2.283       1.99        403
#                  Class     Images  Instances      Box(P          R
#                    all         32        399      0.131       0.14      0.068     0.0168
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       18/30      8.36G      2.388      2.241      1.974        240
#                  Class     Images  Instances      Box(P          R
#                    all         32        399      0.167       0.14     0.0763     0.0194
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       19/30      9.61G      2.383      2.209      1.939        505
#                  Class     Images  Instances      Box(P          R
#                    all         32        399      0.117      0.123     0.0485     0.0135
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       20/30      9.31G      2.362      2.207       1.95        276
#                  Class     Images  Instances      Box(P          R
#                    all         32        399      0.118      0.113     0.0501     0.0154
# Closing dataloader mosaic
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       21/30      7.93G      2.463      2.343      2.048        326
#                  Class     Images  Instances      Box(P          R
#                    all         32        399      0.169      0.125     0.0613     0.0174
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       22/30      8.22G      2.407      2.289      2.056        174
#                  Class     Images  Instances      Box(P          R
#                    all         32        399      0.114      0.125     0.0499     0.0145
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       23/30      8.26G       2.38       2.26      2.021        133
#                  Class     Images  Instances      Box(P          R
#                    all         32        399      0.115      0.125      0.058     0.0185
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       24/30      8.19G      2.341      2.244      1.992        133
#                  Class     Images  Instances      Box(P          R
#                    all         32        399      0.143      0.123     0.0585     0.0169
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       25/30      8.24G      2.334      2.199       1.99        143
#                  Class     Images  Instances      Box(P          R
#                    all         32        399       0.15      0.145      0.072     0.0212
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       26/30      8.47G      2.302       2.17      1.961        128
#                  Class     Images  Instances      Box(P          R
#                    all         32        399      0.167      0.128      0.073     0.0199
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       27/30      8.53G      2.289       2.15      1.956        189
#                  Class     Images  Instances      Box(P          R
#                    all         32        399      0.139      0.153     0.0651     0.0188
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       28/30       7.9G      2.256      2.102       1.93        214
#                  Class     Images  Instances      Box(P          R
#                    all         32        399      0.137       0.14     0.0623     0.0184
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       29/30       7.9G      2.254      2.082      1.919        216
#                  Class     Images  Instances      Box(P          R
#                    all         32        399      0.139      0.133     0.0563     0.0151
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       30/30      7.86G      2.215      2.041      1.907        197
#                  Class     Images  Instances      Box(P          R
#                    all         32        399      0.144      0.139     0.0683     0.0185
#
# 30 epochs completed in 0.083 hours.
# Optimizer stripped from runs\detect\train6\weights\last.pt, 22.5MB
# Optimizer stripped from runs\detect\train6\weights\best.pt, 22.5MB
#
# Validating runs\detect\train6\weights\best.pt...
# Ultralytics YOLOv8.0.196  Python-3.10.11 torch-2.0.1+cu117 CUDA:0 (NVIDIA GeForce RTX 4070 Ti, 12282MiB)
# Model summary (fused): 168 layers, 11125971 parameters, 0 gradients, 28.4 GFLOPs
#                  Class     Images  Instances      Box(P          R
#                    all         32        399      0.151      0.143     0.0716     0.0214
# Speed: 0.1ms preprocess, 4.0ms inference, 0.0ms loss, 2.0ms postprocess per image
# Results saved to runs\detect\train6
#  Learn more at https://docs.ultralytics.com/modes/train
# (myvenv) PS C:\Users\Marcus\Desktop\Share Folder\yolov8-rust-detection>

# %%
# !dir runs\detect\train6\
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is 1C5A-ED5E
#
#  Directory of c:\Users\Marcus\Desktop\Share Folder\yolov8-rust-detection\runs\detect\train6
#
# 04/20/2024  09:55 PM    <DIR>          .
# 04/20/2024  09:49 PM    <DIR>          ..
# 04/20/2024  09:49 PM             1,570 args.yaml
# 04/20/2024  09:55 PM            88,205 confusion_matrix.png
# 04/20/2024  09:55 PM            85,105 confusion_matrix_normalized.png
# 04/20/2024  09:55 PM            76,003 F1_curve.png
# 04/20/2024  09:50 PM           191,041 labels.jpg
# 04/20/2024  09:50 PM           243,923 labels_correlogram.jpg
# 04/20/2024  09:55 PM            83,665 PR_curve.png
# 04/20/2024  09:55 PM           120,675 P_curve.png
# 04/20/2024  09:55 PM            10,447 results.csv
# 04/20/2024  09:55 PM           319,529 results.png
# 04/20/2024  09:55 PM            82,930 R_curve.png
# 04/20/2024  09:50 PM           864,325 train_batch0.jpg
# 04/20/2024  09:50 PM           852,062 train_batch1.jpg
# ...

# %%
from IPython.display import Image

# Now use the Image class to display your image
Image(filename='runs\\detect\\train6\\confusion_matrix.png', width=600)

# %%
Image(filename='runs\\detect\\train6\\results.png', width=600)

# %%
Image(filename='runs\\detect\\train6\\val_batch0_pred.jpg', width=600)

# %%
# !yolo task=detect mode=val model=runs"\\detect\\train6\\weights\\best.pt" data="C:\\Users\\Marcus\\Desktop\\Share Folder\\yolov8-rust-detection\\rust_detection-1\\data.yaml"
# Out:
# Ultralytics YOLOv8.0.196  Python-3.10.11 torch-2.0.1+cu117 CUDA:0 (NVIDIA GeForce RTX 4070 Ti, 12282MiB)
# Model summary (fused): 168 layers, 11125971 parameters, 0 gradients, 28.4 GFLOPs
#
# val: Scanning C:\Users\Marcus\Desktop\Share Folder\yolov8-rust-detection\rust_detection-1\valid\labels.cache... 32 images, 2 backgrounds, 0 corrupt: 100%|██████████| 32/32 [00:00<?, ?it/s]
# val: Scanning C:\Users\Marcus\Desktop\Share Folder\yolov8-rust-detection\rust_detection-1\valid\labels.cache... 32 images, 2 backgrounds, 0 corrupt: 100%|██████████| 32/32 [00:00<?, ?it/s]
#
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95):   0%|          | 0/2 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95):  50%|█████     | 1/2 [00:02<00:02,  2.79s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 2/2 [00:03<00:00,  1.32s/it]
# ...

# %%
# !yolo task=detect mode=predict model=runs"\\detect\\train6\\weights\\best.pt" conf=0.25 source="C:\Users\Marcus\Desktop\Share Folder\yolov8-rust-detection\rust_detection-1\test\images" save=True
# Out:
# Ultralytics YOLOv8.0.196  Python-3.10.11 torch-2.0.1+cu117 CUDA:0 (NVIDIA GeForce RTX 4070 Ti, 12282MiB)
# Model summary (fused): 168 layers, 11125971 parameters, 0 gradients, 28.4 GFLOPs
#
# image 1/23 C:\Users\Marcus\Desktop\Share Folder\yolov8-rust-detection\rust_detection-1\test\images\000016_jpg.rf.a9c94982af0cfc5d23dd6ee5d94be4ec.jpg: 800x800 3 rusts, 6.5ms
# image 2/23 C:\Users\Marcus\Desktop\Share Folder\yolov8-rust-detection\rust_detection-1\test\images\000022_jpg.rf.998c22c726b3b8f144538622063f834d.jpg: 800x800 (no detections), 6.5ms
# image 3/23 C:\Users\Marcus\Desktop\Share Folder\yolov8-rust-detection\rust_detection-1\test\images\000030_jpg.rf.7eedc00cd14fb1837696db9443ce5742.jpg: 800x800 2 rusts, 6.0ms
# image 4/23 C:\Users\Marcus\Desktop\Share Folder\yolov8-rust-detection\rust_detection-1\test\images\000035_jpg.rf.d37bfbcd641a018d2a80e9f90443a536.jpg: 800x800 (no detections), 6.5ms
# ...

# %%
import glob
from IPython.display import Image, display

# Using forward slashes or double backslashes in the path
for image_path in glob.glob('runs/detect/predict/*.jpg')[:3]:
    display(Image(filename=image_path, width=600))
    print("\n")
